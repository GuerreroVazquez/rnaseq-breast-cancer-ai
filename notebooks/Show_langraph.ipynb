# %%
pwd
# Out:
# '/home/karen/Documents/GitHub/rnaseq-breast-cancer-ai/notebooks'

# %% [markdown]
# Agent flow

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
import agent.global_variables
import agent.node_constructor
import agent.node_chatbot
import agent.node_literature
import agent.node_plot
import agent.graph_state
import agent.instructions
import agent.plot_functions
import agent.nodes

from agent.langraph_model import get_agent
agent = get_agent()
# Out:
# 2025-07-09 12:42:25,389 - INFO - NumExpr defaulting to 8 threads.

# %%
from IPython.display import display, Image, Markdown # Grouped
graph_plot = Image(agent.get_graph().draw_mermaid_png())

display(graph_plot)
