# %% [markdown]
# This is the test for the functions working in the model

# %%
import os, sys
sys.path.append(os.path.abspath('../'))
from agent.langraph_model import get_agent
from agent.model_functions import *
import pandas as pd
agent = get_agent()

# %%
clinical_vars = clinincal_variables_needed
test_df = pd.DataFrame(columns=clinical_vars)
# Example patient data

# %%
len(selected_genes)

# %% [markdown]
# validate_data checks if all the columns needed for the columns

# %%
validate_data(data=test_df, data_type='clinical_features')

# %%
# add fake  row to test_df
test_df.loc[0] = [0,0,0,0,0]

# %%
predict_survival_outcome(clinical_features = test_df)

# %%
expression_matrix = "../user/First_10_people.csv"
# Load dataframe
expression_matrix_df = pd.read_csv(expression_matrix)
expression_matrix_df.head()

# %%
test_df= expression_matrix_df.iloc[:10, :].copy()

# %%
validate_data(data=test_df, data_type='gene_expression')

# %%
clinical = predict_clinical_features(gene_expression_data=test_df[selected_genes])

# %%
validate_data(data=clinical, data_type='clinical_features')

# %%
clinical['age at diagnosis'] = [70, 60, 50, 40, 30, 20, 10, 80, 90, 100]
clinical['tumor size'] = [11, 100, 50, 20, 30, 40, 60, 70, 80, 90]
validate_data(data=clinical, data_type='clinical_features')

# %%
predict_survival_outcome(clinical_features = clinical, chemo=True, endo=True)

# %%
(best_treatment, prob) = recommend_treatment(clinical)
